# %%
import numpy as np
from numpy import random

# %%
names = ['Bob', 'Jhon', 'Aman', 'Yash', 'Remy', 'Bob', 'Terry', 'Bob']
ages = [1, 2, 3, 4, 5, 6, 7, 8]

# %%
name = np.array(names)
age = np.array(age)

# %%
# check the names where name is equal to Bob 
name == 'Bob'
# Out:
# array([ True, False, False, False, False,  True, False,  True])

# %%
# check the age of people whose names are 
age[name == 'Bob']
# Out:
# array([1, 6, 8])
